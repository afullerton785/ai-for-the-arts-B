# %% [markdown]
# # Working with Cultural Heritage

# %% [markdown]
# ### For my work with cultural heritage and AI, I have chosen to focus on the Paisley Pattern. I first asked Copilot to give me an overview on what paisley pattern is. This was the result:
#
# The **Paisley pattern** is a decorative design featuring a distinctive **teardrop‑shaped motif with a curved upper end**—often called a *boteh*, *buta*, or *Persian pick*. Here’s a clear breakdown of what it is and why it’s significant:
#
# ***
#
# ## 🌿 **What the Paisley Pattern Is**
#
# *   A repeated motif shaped like a **droplet**, **almond**, or **comma**, often filled with intricate floral or geometric details.
# *   Highly ornamental, commonly seen in **textiles**, **fashion**, **shawls**, **ties**, **scarves**, **bandanas**, home décor, and even modern graphic design.
#
# ***
#
# ## 🏛️ **Where It Originated**
#
# *   **Ancient Persia (modern Iran)**: The motif dates back over 2,000 years. In Persian culture, the shape symbolized **life**, **fertility**, and **eternity**.
# *   It spread through **India**, especially Kashmir, where artisans produced luxurious wool shawls with exquisite boteh designs.
#
# ***
#
# ## 🧵 **Why It’s Called “Paisley”**
#
# *   In the **19th century**, demand for Kashmiri shawls grew in Europe.
# *   Textile mills in **Paisley, Scotland** became the most prolific European producers.
# *   Because Paisley mills dominated production, the design eventually became widely known as the **Paisley pattern**.
#
# *(Fun fact: Paisley’s mills were so influential that the town name became synonymous with the motif worldwide.)*
#
# ***
#
# ## 🎨 **How It’s Used Today**
#
# *   A staple of **fashion**, especially in:
#     *   Bandanas
#     *   Ties and pocket squares
#     *   Dresses and shirts
#     *   High-end designer prints
# *   A recurring trend in **boho, retro,** and **psychedelic** styles.
# *   Often used to evoke richness, heritage, or a slightly vintage aesthetic.
#
# ***
#
# If you’d like, I can also show:
#
# *   Examples of Paisley designs (generated images)
# *   A short history focused on Scotland
# *   How Paisley became linked with 1960s counterculture
#
# Just let me know!
#
# ### Fact Checking
#
# This response from Copilot seems overall to be true, however the only inconsistancy seems to be the origin of the pattern, as there are many conflicting sources that switch between Persia and India as being the source.
#
# ### Image Generation
#
# I then asked Copilot to give me an example of Paisley Pattern. I wanted to do this so I could compare the image generation of different AI tools, so I also asked artbreeder to generate an example. This was the results

# %%
from IPython.display import Image

Image ("Artbreeder_PaisleyPatternTest.jpeg")

# %%
from IPython.display import Image
Image ("Copilot_PaisleyPatternTest.jpeg")

# %% [markdown]
# Comparing the two tools it is clear that Copilot has made the much better generation of Paisley pattern, as the Artbreeder attempt is more of a blurry mess.
