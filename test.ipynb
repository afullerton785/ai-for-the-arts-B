# %%
message = "Hello, World!"

print(message)
# Out:
# Hello, World!

# %% [markdown]
# message = "Hello, world!"
#
# This line creates a variable named message. A variable stores data.
#
# print(message)
#
# This tells Python to display the value stored in the variable message.

# %% [markdown]
# This was used to test the functionality of the Jupyter notebook in the new repository and codespace.
